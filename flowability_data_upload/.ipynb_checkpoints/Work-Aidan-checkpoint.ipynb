# %%
import pandas as pd
import numpy as np

# Make numpcy values easier to read.
np.set_printoptions(precision=3, suppress=True)

import torch
import matplotlib.pyplot as plt
import matplotlib as mat
import seaborn as sns
import os
import sys

module_path = os.path.abspath(os.path.join('..'))

# %%
data = pd.read_pickle('data.pkl')

# %%
def train_test_split(data):

# %%
# Out:
#        Curvature  Surface Area  L/W Ratio  W/L Aspect Ratio  \
# 0            0.0      3033.813      1.301             0.768
# 1            0.0      2317.780      1.042             0.960
# 2            0.0      2330.975      1.081             0.925
# 3            0.0      3475.415      1.657             0.603
# 4            0.0      2566.800      1.166             0.858
# ...          ...           ...        ...               ...
# 11313        0.0        38.081      1.328             0.753
# 11314        0.0        37.583      1.363             0.733
# 11315        0.0        36.373      1.239             0.807
# 11316        0.0        36.281      1.166             0.858
# 11317        0.0        35.116      1.322             0.756
#
#        CHull Surface Area  Ellipticity       Flow  Flow Class  \
# 0                3215.587        1.249  20.013333           1
# 1                2408.590        1.019  20.013333           1
# 2                2444.545        1.088  20.013333           1
# 3                3720.222        1.750  20.013333           1
# 4                2666.602        1.158  20.013333           1
# ...                   ...          ...        ...         ...
# 11313              40.815        1.300   0.000000           0
# 11314              40.708        1.301   0.000000           0
# 11315              39.485        1.283   0.000000           0
# 11316              46.203        1.255   0.000000           0
# 11317              40.472        1.339   0.000000           0
#
#                       Powder
# 0      S1VRC0706-3_Excel.txt
# 1      S1VRC0706-3_Excel.txt
# 2      S1VRC0706-3_Excel.txt
# 3      S1VRC0706-3_Excel.txt
# 4      S1VRC0706-3_Excel.txt
# ...                      ...
# 11313   Valimet_6061_SPE.txt
# 11314   Valimet_6061_SPE.txt
# 11315   Valimet_6061_SPE.txt
# 11316   Valimet_6061_SPE.txt
# 11317   Valimet_6061_SPE.txt
#
# [271433 rows x 9 columns]
