# %%
from flowability_data_upload.local.analytics.visualize_pdf import *


x_normal = generate_normal_data()
x_normal2 = generate_normal_data()
x_bimodal = generate_bi_modal_data()

visualize_pdf(x_normal, x_bimodal)
compare_pdf(x_normal, x_bimodal)
# Out:
# {'ks': 0.477, 'p': 2.220446049250313e-15, 'different': True}

# %%
visualize_pdf(x_normal, x_normal2)
compare_pdf(x_normal, x_normal2)
# Out:
# {'ks': 0.026, 'p': 0.8881734182535203, 'different': False}
