# %%
import pandas as pd
import numpy as np


# Make numpcy values easier to read.
np.set_printoptions(precision=3, suppress=True)

import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.layers.experimental import preprocessing

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from flowability_data_upload.Research.main import trymodel, makemodel, modeltest, Data

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
module_path = module_path + "\\flowability_data_upload\\PSD_TurboSync"

#print(module_path)
  
filelist = os.listdir(module_path)
filelist.pop(0)
flowval = pd.read_excel(module_path + "\\" + filelist.pop(0), index_col=9)
flowval
# Out:
#                               Column1                         Column2  \
# Corresponding Excel
# Sample Name                    Vendor                        Material
# S1VRC0706-1_Excel             Praxair                   TruForm 174-2
# S1VRC0706-2_Excel             Praxair                     FE-206-2-VW
# S1VRC0706-3_Excel           AcuPowder         Copper 500A/EM00248-012
# S1VRC0706-4_Excel          H.C.Starck                      AMPERIT 38
# S1VRC0706-5_Excel              Raymor                           CPTi
# S1VRC0706-6_Excel                AP&C  Spherical APA Ti-6Al-4V Powder
# MW_FeMnAl-C_0-45            Molyworks                          FeMnAl
# MW_I_718_0-10               Molyworks                            I718
# Al-Cr_75-Percent_6061_1.1      Solvus                      Al-Cr 6061
# WIP-BC1                        Solvus                         WIP-BC1
# WIP-W2                         Solvus                          WIP-W2
# ...

# %% [raw]
# x = Data()
# x.importpowders()
# data = x.data.copy()
# datalist = x.datalist.copy()
# flow = x.flow.copy()
# noflow = x.noflow.copy()
# flowlist = x.flowpowders.copy()
# noflowlist = x.noflowpowders.copy()

# %%
x = Data()
x.importnewpowders()
data = x.data.copy() 
datalist = x.datalist.copy()
flow = x.flow.copy()
noflow = x.noflow.copy()
flowlist = x.flowpowders.copy()
noflowlist = x.noflowpowders.copy()
alldatalist = x.alldatalist.copy()
# Out:
# ['AEE_WP-301_1-5_AA_3-7.txt', 'Al-Cr_75-Percent_6061_1.1.txt', 'HCS_C103H_+10,-45.txt', 'HCS_C103N1_+10,-45.txt', 'HCS_C103N2_+10,-45.txt', 'HCS_TaH_-230+PAN.txt', 'Lincoln_SHS_7574HV.txt', 'Lincoln_SHS_8000HV.txt', 'Lincoln_SHS_9172HV.txt', 'MW_FeMnAl-C_0-45.txt', 'MW_I_718_0-10.txt', 'MW_SS-17-4_10-45.txt', 'MW_SS-17-4_64-150.txt', 'MW_Ti-Nb-Zr_0-63.txt', 'MW_Ti-Nb-Zr_64-150.txt', 'MW_Ti-Nb_0-63.txt', 'MW_Ti-Nb_64-150.txt', 'PA_Ni-914-3.txt', 'S1VRC0706-1_Excel.txt', 'S1VRC0706-2_Excel.txt', 'S1VRC0706-3_Excel.txt', 'S1VRC0706-4_Excel.txt', 'S1VRC0706-5_Excel.txt', 'S1VRC0706-6_Excel.txt', 'V5_Al-P1015_99.8%-Al.txt', 'V6_Al-P1015_99.8%-Al.txt', 'Valimet_6061_SPE.txt', 'V_AA-2024.txt', 'V_AA-4047.txt', 'V_Al-P1015_99.8%-Al.txt', 'WIP-BC1.txt', 'WIP-C1.txt', 'WIP-W1.txt', 'WIP-W2.txt', '~$AATurboSync_Flowability_HF_Repository.xlsx']
# AEE_WP-301_1-5_AA_3-7.txt
# No Flow
# Al-Cr_75-Percent_6061_1.1.txt
# 64.30333333333333
# HCS_C103H_+10,-45.txt
# No Flow
# HCS_C103N1_+10,-45.txt
# ...

# %%
#AEE_WP-301_1-5_AA_3-7.cvs
#data = pd.read_excel("Al-Cr_75-Percent_6061_1.1.xls")
data = pd.read_csv("Al-Cr_75-Percent_6061_1.1.txt",sep='\t',header=(0))
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-a51fb0944d21> in <module>
#       1 #AEE_WP-301_1-5_AA_3-7.cvs
#       2 #data = pd.read_excel("Al-Cr_75-Percent_6061_1.1.xls")
# ----> 3 data = pd.read_csv("Al-Cr_75-Percent_6061_1.1.txt",sep='\t',header=(0))
#       4 data
#
# ...

# %%
data
# Out:
#             Da       Dp   FWidth  FLength  ELength   EWidth        Volume  \
# 0      395.289  841.622  375.143  514.872  473.644  371.279  3.234010e+07
# 1      173.582  224.557  159.740  225.318  224.493  143.504  2.738494e+06
# 2      158.852  188.774  142.365  185.108  187.479  136.764  2.098834e+06
# 3      154.478  244.085  122.588  249.865  234.009  110.139  1.930170e+06
# 4      127.025  142.402  122.841  141.070  133.147  122.746  1.073165e+06
# ...        ...      ...      ...      ...      ...      ...           ...
# 33834    2.987    3.761    3.010    3.936    3.155    2.822  1.395500e+01
# 33835    2.963    4.005    3.004    4.095    3.264    2.768  1.361900e+01
# 33836    2.855    4.084    3.281    4.537    3.572    2.587  1.218800e+01
# 33837    2.683    3.782    3.203    4.023    3.516    2.385  1.011300e+01
# 33838    2.680    3.702    3.140    4.002    3.548    2.280  1.008000e+01
#
#              Area  Perimeter  CHull  Area  ...  Curvature  Surface Area  \
# ...
